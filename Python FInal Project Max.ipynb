# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import csv

def create_dictionary_from_csv(file_path, key_column, value_column):
    data = {}
    with open(file_path, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            #print(row)
            key= row[key_column]
            value = row[value_column]
            value=int(value)
            data[key] = value
    return data

# %%
file_path = "SPY.csv"
key_column = 'Date'
value_column = "Volume"

Date_Volume = create_dictionary_from_csv(file_path, key_column,value_column)
from pprint import pprint
pprint(Date_Volume )
# Out:
# {'2023-06-08': 61952800,
#  '2023-06-09': 85742800,
#  '2023-06-12': 76104300,
#  '2023-06-13': 95899700,
#  '2023-06-14': 100612100,
#  '2023-06-15': 110303100,
#  '2023-06-16': 114121300,
#  '2023-06-20': 76160400,
#  '2023-06-21': 76982300,
#  '2023-06-22': 70637200,
#  '2023-06-23': 92074500,
#  '2023-06-26': 72823600,
#  '2023-06-27': 72813700,
#  '2023-06-28': 75636000,
#  '2023-06-29': 67882300,
#  '2023-06-30': 104921500,
#  '2023-07-03': 32793400,
#  '2023-07-05': 58418400,
#  '2023-07-06': 80658300,
#  '2023-07-07': 86076100,
#  '2023-07-10': 62443500,
#  '2023-07-11': 64463800,
#  '2023-07-12': 91924500,
#  '2023-07-13': 72425200,
#  '2023-07-14': 69761800,
#  '2023-07-17': 52680200,
#  '2023-07-18': 80744400,
#  '2023-07-19': 65891700,
#  '2023-07-20': 70591600,
#  '2023-07-21': 71245400,
#  '2023-07-24': 54023400,
#  '2023-07-25': 55191200,
#  '2023-07-26': 71052900,
#  '2023-07-27': 92194400,
#  '2023-07-28': 80011800,
#  '2023-07-31': 62040400,
# ...

# %% [markdown]
# # length of dictionary

# %%
res = len(Date_Volume)
print("The length of the dictionary is: ", res)
# Out:
# The length of the dictionary is:  252

# %% [markdown]
# # Biggest and smallest values

# %%
print(max(Date_Volume.values()))
print(max(Date_Volume,key=Date_Volume.get))
# Out:
# 141319300
# 2023-12-15

# %%
print(min(Date_Volume.values()))

print(min(Date_Volume,key=Date_Volume.get))
# Out:
# 29737400
# 2023-11-24
